# %% [markdown]
# # Standard Deviation

# %%
import numpy as np
speed = [86,87,88,86,87,85,86]
x=np.std(speed)
print(x)
# Out:
# 0.9035079029052513

# %% [markdown]
# # Variance

# %%
speed = [32,111,138,28,59,77,97]
y=np.var(speed)
print(y)
# Out:
# 1432.2448979591834
