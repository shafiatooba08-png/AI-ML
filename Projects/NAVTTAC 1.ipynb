# %% [markdown]
# # Task 1

# %% [markdown]
# ADD two numbers

# %%
num1=1.5
num2=6.3
sum=num1+num2
#print('the sum of {0} and  {1} is {2}'.format(num1,num2,sum))old way
print(f'the sum of {num1} and {num2} is {sum}')
# Out:
# the sum of 1.5 and 6.3 is 7.8

# %% [markdown]
# # Task 2

# %% [markdown]
# Store input numbers

# %%
num1=input('Enter num1')
num2=input('Enter num2')
sum=int(num1)+int(num2)
print(f'The sum of {num1} and {num2} is {sum}')
# Out:
# Enter num1 5
# Enter num2 7
# The sum of 5 and 7 is 12

# %% [markdown]
# # Task 3

# %% [markdown]
# SQUARE root

# %%
import math
num=8
squareroot=num**0.5
print(squareroot)
# METHOD 2
sqrt=math.sqrt(num)
print(f'the square root of {num} is {sqrt:.2f}')
# Out:
# 2.8284271247461903
# the square root of 8 is 2.83

# %% [markdown]
# # Task 4

# %%
import cmath
num=1+2j
sqrt=cmath.sqrt(num)
print(f'the squareroot of {num} is {sqrt.real:.2f}+{sqrt.imag:.2f}')
# Out:
# the squareroot of (1+2j) is 1.27+0.79

# %% [markdown]
# # Task 5

# %% [markdown]
# convert Temperature

# %%
celsius=37.5
fahrenheit=(celsius*1.8)+32
print(f'{celsius}  degree celsius is equal to {fahrenheit} degree fahranheit')
# Out:
# 37.5  degree celsius is equal to 99.5 degree fahranheit

# %% [markdown]
# # Task 6

# %% [markdown]
# Area of the triangle

# %%
a=5
b=6
c=7
s=(a+b+c)/2
area=math.sqrt(s*(s-a)*(s-b)*(s-c))
print(f'The area of the triangle is {area:.2f}')
# Out:
# The area of the triangle is 14.70

# %% [markdown]
# # Task 7

# %% [markdown]
# Quadratic equation

# %%
a=1
b=5
c=6
d=b**2-4*a*c
sol1=(-b+cmath.sqrt(d))/2*a
sol2=(-b-cmath.sqrt(d))/2*a
print(f'the solution {sol1} , {sol2}')
# Out:
# the solution (-2+0j) , (-3+0j)

# %% [markdown]
# # Task 8

# %%
kilometers=float(input('Enter value in kilometer :'))
conv_fav=0.621371
miles=kilometers*conv_fav
print(miles)
# Out:
# Enter value in kilometer : 20
# 12.42742

# %% [markdown]
# # Task 9

# %%
i=10
if i>15 :
    print('i is grater than 15')

# %% [markdown]
# # Task 10

# %%
marks=float(input('Please enter your marks'))
if marks>=50:
    if marks>=90:
        print("A Grade")
    elif marks>=80:
        print("B Grade")
    elif marks>=70:
        print("C Grade")
    elif marks >= 50:       
        print("D Grade")
else:
    print("Fail")
# Out:
# Please enter your marks 12
# Fail

# %% [markdown]
# # Task 11

# %%
Balance = float(input("Please enter your balance"))
if Balance > 0:
    if Balance >= 500:
        if Balance <= 5000:
           print(f'{Balance} transaction completed ')
        else:
            print("you cannot withdraw money more than 5000")
    else:
        print('amount is less than 500')
else:
   print('your balance is insifficient ')
# Out:
# Please enter your balance 550
# 550.0 transaction completed

# %% [markdown]
# # Task 12

# %% [markdown]
# For LOOP

# %%
for i in range(1,6):
  print(i)
name='shafia'
for i in name:
    print(i)
numbers = [10, 20, 30, 40, 50]
for i in numbers:
    print(i)
table=int(input('Please enter the number'))
for i in range(1,11):
    p=table*i
    print(f'{table} * {i}= {p}')
for i in range(1,11):
    if i==5:
      continue
    print(i)
wordlist = ["admin", "1234", "root", "toor", "kali", "python"]
correct_password = "pakistan"
for i in wordlist:
    if correct_password==i:
        print('Access Granted')
        break
    print(f"Trying: {i}")
else:
         print("Access Denied!")
for index,word in enumerate(wordlist,1):
    print(f'Attempt {index}: {word}')
usernames = ["admin", "root"]
passwords = ["1234", "kali", "toor"]
for i in usernames:
    for j in passwords:
            print(f'Trying:{i} + {j}')
# Out:
# 1
# 2
# 3
# 4
# 5
# s
# h
# a
# f
# i
# a
# 10
# 20
# 30
# 40
# 50
# Please enter the number 3
# 3 * 1= 3
# 3 * 2= 6
# 3 * 3= 9
# 3 * 4= 12
# 3 * 5= 15
# 3 * 6= 18
# 3 * 7= 21
# 3 * 8= 24
# 3 * 9= 27
# 3 * 10= 30
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10
# Trying: admin
# Trying: 1234
# Trying: root
# Trying: toor
# Trying: kali
# Trying: python
# Access Denied!
# Attempt 1: admin
# Attempt 2: 1234
# Attempt 3: root
# Attempt 4: toor
# Attempt 5: kali
# Attempt 6: python
# Trying:admin + 1234
# Trying:admin + kali
# Trying:admin + toor
# Trying:root + 1234
# Trying:root + kali
# Trying:root + toor

# %% [markdown]
# # TASK 13

# %% [markdown]
# While loop

# %%
i=1
while i<=5:
 print(i)
 i+=1
password=''
correct_password = "kali"
while  correct_password!=password:
    password=input('please enter your password')
    if correct_password==password:
        print('Access Granted!')
    else:
        print('Wrong! Try again.')
i=1
while i<=10:
    if i == 7:
        i += 1      
        continue    
    print(i)
    i += 1   
i=1
while i<10:
 if i==7:
    break
 print(i)
 i += 1 
correct_password='786@'
i=1
while i<=3:
  password=input('plese enter your password ')
  if password!=correct_password:
     print('Wrong!')
  else:
      print('lgoin successfully')
      break
  i+=1
else:
    print('System Locked!')
# Out:
# plese enter your password  3422
# Wrong!
# plese enter your password  786@
# lgoin successfully

# %% [markdown]
# # Task 14

# %% [markdown]
# Break statement

# %%
emails = ["admingmail.com", "useryahoo", "shafia@gmail.com", "test@hotmail.com"]
for i in emails:
    if "@" in i:
        print(f'Checking: {i}- Valid! found.')
        break
    else:
        print(f'Checking: {i} -Invalid')
# Out:
# Checking: admingmail.com -Invalid
# Checking: useryahoo -Invalid
# checking: shafia@gmail.com-found

# %% [markdown]
# # TASK 15

# %% [markdown]
# Continue statement

# %%
sales = ["1200", "", "850", "", "3400", "900", ""]
for i in sales:
    if i=="":
       continue
    print(f'sales: {i}')
# Out:
# sales: 1200
# sales: 850
# sales: 3400
# sales: 900
