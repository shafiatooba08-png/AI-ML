# %%
foods=['pizza','rice', 'burger','fries','pasta']
print(foods)
print(foods[0])  
print(foods[-1])  
print(foods[2])
print(foods[1:-1])
print(foods[0:3])
print(foods[-2:])
# Out:
# ['pizza', 'rice', 'burger', 'fries', 'pasta']
# pizza
# pasta
# burger
# ['rice', 'burger', 'fries']
# ['pizza', 'rice', 'burger']
# ['fries', 'pasta']

# %%
foods = ['pizza', 'rice', 'burger', 'fries', 'pasta']
foods.append('biryani')
print(foods)
# Out:
# ['pizza', 'rice', 'burger', 'fries', 'pasta', 'biryani']

# %%
foods = ['pizza', 'rice', 'burger', 'fries', 'pasta']
foods.insert(2,'nihari')
print(foods)
# list.insert(index, item)
# Out:
# ['pizza', 'rice', 'nihari', 'burger', 'fries', 'pasta']

# %%
foods = ['pizza', 'rice']
desi_foods = ['biryani', 'nihari', 'halwa']
desi_foods.extend(foods)
print(desi_foods)
# Out:
# ['biryani', 'nihari', 'halwa', 'pizza', 'rice']

# %%
foods = ['pizza', 'rice', 'burger', 'fries', 'pasta']
foods[0]='sushi'
foods[-1]= 'biryani' 
print(foods)
# Out:
# ['sushi', 'rice', 'burger', 'fries', 'biryani']

# %%
foods = ['pizza', 'rice', 'burger', 'fries', 'pasta']
foods.remove('burger')
print(foods)
del foods[0]
print(foods)
# Out:
# ['pizza', 'rice', 'fries', 'pasta']
# ['rice', 'fries', 'pasta']

# %%
foods = ['pizza', 'rice', 'burger', 'fries', 'pasta']

print(len(foods))
# Out:
# 5

# %%
nums = [5, 2, 9, 1]
nums.sort()
print(nums)
# Out:
# [1, 2, 5, 9]

# %%
nums = [5, 2, 9, 1]
nums.reverse()
print(nums)
# Out:
# [1, 9, 2, 5]
