# %% [markdown]
# # COPY:

# %% [markdown]
# attribute base that returns None if the array owns the data.

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
copy=arr.copy()
arr[0]=2
print(arr)
print(copy)
print(copy.base)
# Out:
# [2 2 3 4 5]
# [1 2 3 4 5]
# None

# %% [markdown]
# As mentioned above, copies owns the data, and views does not own the data, but how can we check this?

# %% [markdown]
# # VIEW:

# %%
arr=np.array([1, 2, 3, 4, 5])
view=arr.view()
arr[0]=42
print(arr)
print(view)
print(view.base)
# Out:
# [42  2  3  4  5]
# [42  2  3  4  5]
# [42  2  3  4  5]

# %% [markdown]
# Otherwise, the base  attribute refers to the original object.

# %% [markdown]
# ![Screenshot (418).png](attachment:a656f356-6979-4338-a390-380eb10c809c.png)
