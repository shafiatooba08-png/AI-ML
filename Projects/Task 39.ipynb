# %%
import pandas as pd 
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}
df=pd.DataFrame(mydataset)
print(df)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# In programming, an alias is essentially a nickname or a shorter reference for a module, library, or function.

# %% [markdown]
# # Checking Pandas Version

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# ![Screenshot (429).png](attachment:f50766f6-0454-47e2-9ff3-52c2e0ab043c.png)
